# %%
import cv2
import os
from PIL import Image

# %%
def process_image(img, min_side):
    print(img)
    img = cv2.imread(img)
    size = img.shape
    h, w = size[0], size[1]
    #长边缩放为min_side
    scale = max(w, h) / float(min_side)
    new_w, new_h = int(w/scale), int(h/scale)
    resize_img = cv2.resize(img, (new_w, new_h))
    # 填充至min_side * min_side
    if new_w % 2 != 0 and new_h % 2 == 0:
        top, bottom, left, right = (min_side-new_h)/2, (min_side-new_h)/2, (min_side-new_w)/2 + 1, (min_side-new_w)/2
    elif new_h % 2 != 0 and new_w % 2 == 0:
        top, bottom, left, right = (min_side-new_h)/2 + 1, (min_side-new_h)/2, (min_side-new_w)/2, (min_side-new_w)/2
    elif new_h % 2 == 0 and new_w % 2 == 0:
        top, bottom, left, right = (min_side-new_h)/2, (min_side-new_h)/2, (min_side-new_w)/2, (min_side-new_w)/2
    else:
        top, bottom, left, right = (min_side-new_h)/2 + 1, (min_side-new_h)/2, (min_side-new_w)/2 + 1, (min_side-new_w)/2
    pad_img = cv2.copyMakeBorder(resize_img, int(top), int(bottom), int(left), int(right), cv2.BORDER_CONSTANT, value=[0,0,0]) #从图像边界向上,下,左,右扩的像素数目

    return pad_img

# %%
if __name__ == '__main__':
    path = '/project/train/scr_repo1/data2'
    for file in os.listdir(path):
        print(file)
        for img_file in os.listdir(os.path.join(path,file)):
    #         print(img_file)
            img_path = os.path.join(path,file,img_file)
            if not img_path.endswith(".jpg"):
                continue
            out_path = os.path.join("/project/train/scr_repo1/data3",file)
            out_img = os.path.join("/project/train/scr_repo1/data3",file,img_file)
            if not os.path.exists(out_path):
                os.makedirs(out_path)
            if os.path.exists(out_img):
                continue
            pad_img = process_image(img_path, 48)
            im = Image.fromarray(pad_img)
            im.save(out_img)
# Out:
# happy
# sad
# /project/train/scr_repo1/data2/sad/2c085baa96c041d3b39a972eb61f40f7.jpg
# fear
# /project/train/scr_repo1/data2/fear/3ac21290c8eb48788fedc6b92492323d.jpg
# /project/train/scr_repo1/data2/fear/56e8e9558cc14978acb994a44dbec17f.jpg
# /project/train/scr_repo1/data2/fear/a9e0832960ac4845bbad62e33ab62a0d.jpg
# /project/train/scr_repo1/data2/fear/9350f9d7c58a424b90d98ad553bd2a0b.jpg
# /project/train/scr_repo1/data2/fear/20c6e1c04bfc45b6873d0f9f12552c2d.jpg
# /project/train/scr_repo1/data2/fear/75b2c9fc7671403bb1c1935d7b8cc6e6.jpg
# /project/train/scr_repo1/data2/fear/4139b41bb387429686fd58214b16adc8.jpg
# /project/train/scr_repo1/data2/fear/88614d96a0ec45e0830b1ba85a32e3f7.jpg
# /project/train/scr_repo1/data2/fear/1d76bd4e3b704c54a2e9eaaba7e55050.jpg
# /project/train/scr_repo1/data2/fear/0face8602bae41c7b0dfbb19557c746a.jpg
# /project/train/scr_repo1/data2/fear/3e5be16283f64d66a23336123f5af538.jpg
# /project/train/scr_repo1/data2/fear/29f00dbcef0442fbbb2972964245493f.jpg
# /project/train/scr_repo1/data2/fear/8297af65231940f1b84e6cb488ea42db.jpg
# neutral
# /project/train/scr_repo1/data2/neutral/1a8ce4fe978845beb8e4b54291bdcbc7.jpg
# /project/train/scr_repo1/data2/neutral/01f0ba0ddb854920b13b579601d63fcd.jpg
# /project/train/scr_repo1/data2/neutral/1d0a6a95bd334b37aabc0deada8568c0.jpg
# /project/train/scr_repo1/data2/neutral/0cd630273aec4d24aba19efcd851f4d9.jpg
# /project/train/scr_repo1/data2/neutral/0feea31aca0542afb8dadf012848eebb.jpg
# /project/train/scr_repo1/data2/neutral/0c2c7728656b4a48b7dab6f0b3200c3b.jpg
# /project/train/scr_repo1/data2/neutral/1b6e3460206e48d3ba4c71c25ea5f2cb.jpg
# /project/train/scr_repo1/data2/neutral/0b1d429c871c48b3b458aa6b9b9a8319.jpg
# /project/train/scr_repo1/data2/neutral/00f8c28dde384100bfc085fcb2eedef7.jpg
# /project/train/scr_repo1/data2/neutral/1c3c59ab897f44a3a087ea237b212c04.jpg
# /project/train/scr_repo1/data2/neutral/0b4e2fce5d01454cbecaa8239f20526a.jpg
# /project/train/scr_repo1/data2/neutral/1d284cae9add45d5bb36188af23e2091.jpg
# angry
# /project/train/scr_repo1/data2/angry/f669b01fa2b7464ab34712660df44329.jpg
# /project/train/scr_repo1/data2/angry/53a5e9ee00e54b7993228a773800b88e.jpg
# /project/train/scr_repo1/data2/angry/37dd077bd3ee4e00b5ee7c0b3c015e0f.jpg
# /project/train/scr_repo1/data2/angry/f99644a3da3b4634a7841d323b837e45.jpg
# /project/train/scr_repo1/data2/angry/4ff24285645b44ed85729738f7d3be4a.jpg
# /project/train/scr_repo1/data2/angry/b4fcb3eb75724f18becfb1512d623b68.jpg
# /project/train/scr_repo1/data2/angry/1de1c664323b48ec9fd92c37196e137d.jpg
# /project/train/scr_repo1/data2/angry/df89c4ee7cc642d5800d0e379a741cb0.jpg
# /project/train/scr_repo1/data2/angry/d4d2ba3b67454954ad20d3d64252d627.jpg
# /project/train/scr_repo1/data2/angry/dd3412b658954c0387c3062b69c778dd.jpg
# /project/train/scr_repo1/data2/angry/dc4fe5b8efba42dbb786063d804fcf67.jpg
# /project/train/scr_repo1/data2/angry/cfe4199ea40a43bd85aece5b62e5dc77.jpg
# /project/train/scr_repo1/data2/angry/59a258a2fadc461499e62e928821ae93.jpg
# /project/train/scr_repo1/data2/angry/63fcc9e7e1e54584b15541d915751040.jpg
# suprise
# /project/train/scr_repo1/data2/suprise/9a28d1aff6d74b1b84cce01cbb51b901.jpg
# /project/train/scr_repo1/data2/suprise/689a6072c7ba4de3872b001e34aea95c.jpg
# /project/train/scr_repo1/data2/suprise/2fda816b785b4c7cb9c4c532acb0991e.jpg
# /project/train/scr_repo1/data2/suprise/9008a5960234444ea1ac77c83badb2d1.jpg
# /project/train/scr_repo1/data2/suprise/46fa040c07684e8fa58c0da62e9627d1.jpg
# /project/train/scr_repo1/data2/suprise/7d32ec0bc72a40578eed0bfddd9d569b.jpg
# /project/train/scr_repo1/data2/suprise/7ac325ef18054e0d80bf8c2b95446393.jpg
# /project/train/scr_repo1/data2/suprise/3535ccb21d8e4f0eb6122e8aea2dccb0.jpg
# /project/train/scr_repo1/data2/suprise/29625b68333b47cc8709944196304910.jpg
# /project/train/scr_repo1/data2/suprise/2c28c586f8eb47139ff4e5b11f939255.jpg
# /project/train/scr_repo1/data2/suprise/474d37006d9643359af362aadc18b85e.jpg
# /project/train/scr_repo1/data2/suprise/8ceb182333124be099503f1a831a1c1b.jpg
# /project/train/scr_repo1/data2/suprise/59be3284e87f41fc8b703ee93c667403.jpg
# disgust
# /project/train/scr_repo1/data2/disgust/29b7098df99146ff8cd9f46bff18b6fa.jpg
# /project/train/scr_repo1/data2/disgust/c1829aac706243599e896c911dd0de70.jpg
# /project/train/scr_repo1/data2/disgust/157e4efcff8a407b983635da72403029.jpg
# /project/train/scr_repo1/data2/disgust/81974ce9e7fb4766a8d482539e91dea0.jpg
# /project/train/scr_repo1/data2/disgust/594d9a426e494a7b8fe86c2da211d7c4.jpg
# /project/train/scr_repo1/data2/disgust/2fb95ea60e454135b47387417cccd2d0.jpg
# /project/train/scr_repo1/data2/disgust/bf59f6f16aa74c66b6066b9f7d9a7384.jpg
# /project/train/scr_repo1/data2/disgust/488e405a0eb74662922b7ad56e65577f.jpg
# /project/train/scr_repo1/data2/disgust/14ab350e3fd14b2b8946afee211eaf11.jpg
# /project/train/scr_repo1/data2/disgust/b56c5adcf8cd40fab78a3271f93d1b67.jpg
# /project/train/scr_repo1/data2/disgust/094607cb2ece4463936950e992f25985.jpg
# /project/train/scr_repo1/data2/disgust/ab2d246cf22b4b8f96dc0a398bb76424.jpg
