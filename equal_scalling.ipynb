# %%
import cv2
import os
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# %%
def process_image(img, min_side): 
    img=cv2.imread(img,0)
    size = img.shape
    print(size)
    h, w = size[0], size[1]
    #长边缩放为min_side
    scale = max(w, h) / float(min_side)
    new_w, new_h = int(w/scale), int(h/scale)
    resize_img = cv2.resize(img, (new_w, new_h))
    # 填充至min_side * min_side
    if new_w % 2 != 0 and new_h % 2 == 0:
        top, bottom, left, right = (min_side-new_h)/2, (min_side-new_h)/2, (min_side-new_w)/2 + 1, (min_side-new_w)/2
    elif new_h % 2 != 0 and new_w % 2 == 0:
        top, bottom, left, right = (min_side-new_h)/2 + 1, (min_side-new_h)/2, (min_side-new_w)/2, (min_side-new_w)/2
    elif new_h % 2 == 0 and new_w % 2 == 0:
        top, bottom, left, right = (min_side-new_h)/2, (min_side-new_h)/2, (min_side-new_w)/2, (min_side-new_w)/2
    else:
        top, bottom, left, right = (min_side-new_h)/2 + 1, (min_side-new_h)/2, (min_side-new_w)/2 + 1, (min_side-new_w)/2
    pad_img = cv2.copyMakeBorder(resize_img, int(top), int(bottom), int(left), int(right), cv2.BORDER_CONSTANT, value=[0,0,0]) #从图像边界向上,下,左,右扩的像素数目
    print(pad_img.shape)
    return pad_img

# %%
if __name__ == '__main__':
    path = '/home/data/5'
    for file in os.listdir(path):
#         print(file)
        for img_file in os.listdir(os.path.join(path,file)):
    #         print(img_file)
            img_path = os.path.join(path,file,img_file)
            if not img_path.endswith(".jpg"):
                continue
            out_path = os.path.join("/project/train/scr_repo1/data4",file)
            out_img = os.path.join("/project/train/scr_repo1/data4",file,img_file)
            if not os.path.exists(out_path):
                os.makedirs(out_path)
            if os.path.exists(out_img):
                continue
            pad_img = process_image(img_path, 128)
            print(pad_img.shape)
            im = Image.fromarray(pad_img)
            im.save(out_img)
# Out:
# (667, 1000)
# (128, 128)
# (128, 128)
# (240, 315)
# (128, 128)
# (128, 128)
# (317, 453)
# (128, 128)
# (128, 128)
# (956, 960)
# (128, 128)
# (128, 128)
# (362, 233)
# (128, 128)
# (128, 128)
# (250, 250)
# (128, 128)
# (128, 128)
# (113, 168)
# (128, 128)
# (128, 128)
# (390, 280)
# (128, 128)
# (128, 128)
# (535, 800)
# (128, 128)
# (128, 128)
# (1635, 2180)
# (128, 128)
# (128, 128)
# (1600, 1067)
# (128, 128)
# (128, 128)
# (286, 460)
# (128, 128)
# (128, 128)
# (741, 599)
# (128, 128)
# (128, 128)
# (393, 706)
# (128, 128)
# (128, 128)
# (1080, 1080)
# (128, 128)
# (128, 128)
# (1024, 1024)
# (128, 128)
# (128, 128)
# (785, 1166)
# (128, 128)
# (128, 128)
# (325, 325)
# (128, 128)
# (128, 128)
# (360, 480)
# (128, 128)
# (128, 128)
# (426, 640)
# (128, 128)
# (128, 128)
# (380, 570)
# (128, 128)
# (128, 128)
# (381, 634)
# (128, 128)
# (128, 128)
# (188, 236)
# (128, 128)
# (128, 128)
# (589, 636)
# (128, 128)
# (128, 128)
# (334, 450)
# (128, 128)
# (128, 128)
# (467, 700)
# (128, 128)
# (128, 128)
# (825, 640)
# (128, 128)
# (128, 128)
# (236, 368)
# (128, 128)
# (128, 128)
# (360, 640)
# (128, 128)
# (128, 128)
# (409, 615)
# (128, 128)
# (128, 128)
# (200, 360)
# (128, 128)
# (128, 128)
# (675, 1200)
# (128, 128)
# (128, 128)
# (270, 480)
# (128, 128)
# (128, 128)
# (350, 233)
# (128, 128)
# (128, 128)
# (371, 400)
# (128, 128)
# (128, 128)
# (800, 533)
# (128, 128)
# (128, 128)
# (332, 460)
# (128, 128)
# (128, 128)
# (398, 600)
# (128, 128)
# (128, 128)
# (320, 213)
# (128, 128)
# (128, 128)
# (320, 320)
# (128, 128)
# (128, 128)
# (936, 720)
# (128, 128)
# (128, 128)
# (235, 235)
# (128, 128)
# (128, 128)
# (167, 252)
# (128, 128)
# (128, 128)
# (358, 500)
# (128, 128)
# (128, 128)
# (400, 700)
# (128, 128)
# (128, 128)
# (1031, 774)
# (128, 128)
# (128, 128)
# (409, 615)
# (128, 128)
# (128, 128)
# (344, 550)
# (128, 128)
# (128, 128)
# (550, 500)
# (128, 128)
# (128, 128)
# (276, 200)
# (128, 128)
# (128, 128)
# (1575, 1035)
# (128, 128)
# (128, 128)
# (409, 615)
# (128, 128)
# (128, 128)
# (399, 465)
# (128, 128)
# (128, 128)
# (276, 460)
# (128, 128)
# (128, 128)
# (263, 262)
# (128, 128)
# (128, 128)
# (250, 250)
# (128, 128)
# (128, 128)
# (270, 330)
# (128, 128)
# (128, 128)
# (300, 300)
# (128, 128)
# (128, 128)
# (264, 314)
# (128, 128)
# (128, 128)
# (300, 425)
# (128, 128)
# (128, 128)
# (303, 450)
# (128, 128)
# (128, 128)
# (232, 190)
# (128, 128)
# (128, 128)
# (181, 300)
# (128, 128)
# (128, 128)
# (271, 464)
# (128, 128)
# (128, 128)
# (260, 415)
# (128, 128)
# (128, 128)
# (400, 295)
# (128, 128)
# (128, 128)
# (665, 1000)
# (128, 128)
# (128, 128)
# (507, 760)
# (128, 128)
# (128, 128)
# (300, 200)
# (128, 128)
# (128, 128)
# (1000, 2000)
# (128, 128)
# (128, 128)
# (160, 117)
# (128, 128)
# (128, 128)
# (347, 524)
# (128, 128)
# (128, 128)
# (235, 156)
# (128, 128)
# (128, 128)
# (240, 312)
# (128, 128)
# (128, 128)
# (900, 1600)
# (128, 128)
# (128, 128)
# (442, 380)
# (128, 128)
# (128, 128)
# (326, 500)
# (128, 128)
# (128, 128)
# (203, 275)
# (128, 128)
# (128, 128)
# (168, 113)
# (128, 128)
# (128, 128)
# (293, 570)
# (128, 128)
# (128, 128)
# (360, 480)
# (128, 128)
# (128, 128)
# (1000, 2000)
# (128, 128)
# (128, 128)
# (500, 500)
# (128, 128)
# (128, 128)
# (828, 1200)
# (128, 128)
# (128, 128)
# (700, 700)
# (128, 128)
# (128, 128)
# (506, 900)
# (128, 128)
# (128, 128)
# (348, 640)
# (128, 128)
# (128, 128)
# (423, 284)
# (128, 128)
# (128, 128)
# (175, 175)
# (128, 128)
# (128, 128)
# (257, 236)
# (128, 128)
# (128, 128)
# (270, 480)
# (128, 128)
# (128, 128)
# (425, 640)
# (128, 128)
# (128, 128)
# (960, 640)
# (128, 128)
# (128, 128)
# (693, 553)
# (128, 128)
# (128, 128)
# (300, 590)
# (128, 128)
# (128, 128)
# (300, 200)
# (128, 128)
# (128, 128)
# (700, 600)
# (128, 128)
# (128, 128)
# (350, 600)
# (128, 128)
# (128, 128)
# (636, 950)
# (128, 128)
# (128, 128)
# (427, 640)
# (128, 128)
# (128, 128)
